# %%
#import needed libraries
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('postgresql://read_only_user@datathon.data-lab.io:5432/postgres')
import numpy as np
from sklearn import preprocessing

import nltk
nltk.download('stopwords')

# %%
#select dat from provided postgres databse
sql = "select description from public.standard where cast(pubdate as date) between '2018-01-01' and '2018-04-20' and length(description)>0;"
data = pd.read_sql_query(sql,con=engine)
data.head()
# Out:
#                                          description
# 0  Sieg an Norweger Schmid, Rehrl Siebenter, Grub...
# 1    Zunächst keine Berichte über Schäden oder Opfer
# 2                          Neuer Spot für den Cactus
# 3                 Sechster Sieg für Toronto in Folge
# 4  Polizei: Gruppe plante größeren Sprengstoffans...

# %%
#tokenize the articles into list of words
#with stopwords we are removing useless general words
from nltk.tokenize.casual import casual_tokenize
tokenizer = lambda text: casual_tokenize(text, preserve_case=False)
LabeledSentence = gensim.models.doc2vec.TaggedDocument
content = []
j=0

from nltk.corpus import stopwords
stopWords = set(stopwords.words('german'))




tokens_orig = data['description'].apply(tokenizer)
tokens_orig = list(tokens)

#final clean-up of the tokens
tokens = []
for token_orig in tokens_orig:
    token = []
    for word in token_orig:
        #if (word not in stopWords and ['.' , '!', ',', '?', '"', ':', '-', ' ', '|'] not in word):
        if (word not in stopWords and bool(re.match('^[A-z]+$', word))):
            token.append(word)
    tokens.append(token)
            
            
#prepare labeled sentences dataset do doc2vec alg
for token in tokens:
    content.append(LabeledSentence(token,[j]))
    j+=1

# %%
#train shallow neural network doc2vec and compute senteces vectors for further analysis 
import gensim, logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

d2v_model = gensim.models.Doc2Vec(content, size = 200, window = 10, min_count = 50, workers=7, dm = 1, 
                alpha=0.025, min_alpha=0.001)
# Out:
# /user/ivo.brydl/.local/lib/python3.4/site-packages/gensim/models/doc2vec.py:366: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# 2018-04-21 13:04:34,152 : INFO : collecting all words and their counts
# 2018-04-21 13:04:34,153 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2018-04-21 13:04:34,203 : INFO : PROGRESS: at example #10000, processed 62317 words (1273710/s), 22205 word types, 10000 tags
# 2018-04-21 13:04:34,251 : INFO : collected 35437 word types and 20000 unique tags from a corpus of 20000 examples and 125206 words
# 2018-04-21 13:04:34,251 : INFO : Loading a fresh vocabulary
# 2018-04-21 13:04:34,271 : INFO : min_count=50 retains 238 unique words (0% of original 35437, drops 35199)
# 2018-04-21 13:04:34,272 : INFO : min_count=50 leaves 26575 word corpus (21% of original 125206, drops 98631)
# 2018-04-21 13:04:34,273 : INFO : deleting the raw counts dictionary of 35437 items
# 2018-04-21 13:04:34,274 : INFO : sample=0.001 downsamples 150 most-common words
# 2018-04-21 13:04:34,275 : INFO : downsampling leaves estimated 18009 word corpus (67.8% of prior 26575)
# 2018-04-21 13:04:34,277 : INFO : estimated required memory for 238 words and 200 dimensions: 16499800 bytes
# 2018-04-21 13:04:34,277 : INFO : resetting layer weights
# 2018-04-21 13:04:34,594 : INFO : training model with 7 workers on 238 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2018-04-21 13:04:35,601 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-04-21 13:04:35,990 : INFO : EPOCH 1 - PROGRESS: at 60.37% examples, 16512 words/s, in_qsize 5, out_qsize 1
# 2018-04-21 13:04:35,992 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-04-21 13:04:36,256 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-04-21 13:04:36,268 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-04-21 13:04:36,275 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-21 13:04:36,278 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-21 13:04:36,280 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-21 13:04:36,281 : INFO : EPOCH - 1 : training on 125206 raw words (37947 effective words) took 1.7s, 22600 effective words/s
# 2018-04-21 13:04:37,278 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-04-21 13:04:37,839 : INFO : EPOCH 2 - PROGRESS: at 60.37% examples, 14828 words/s, in_qsize 5, out_qsize 1
# 2018-04-21 13:04:37,841 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-04-21 13:04:38,188 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-04-21 13:04:38,203 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-04-21 13:04:38,215 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-21 13:04:38,219 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-21 13:04:38,223 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-21 13:04:38,224 : INFO : EPOCH - 2 : training on 125206 raw words (38023 effective words) took 1.9s, 19647 effective words/s
# 2018-04-21 13:04:39,398 : INFO : EPOCH 3 - PROGRESS: at 7.75% examples, 2618 words/s, in_qsize 12, out_qsize 0
# 2018-04-21 13:04:39,469 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-04-21 13:04:39,859 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-04-21 13:04:40,119 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-04-21 13:04:40,145 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-04-21 13:04:40,148 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-21 13:04:40,150 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-21 13:04:40,151 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-21 13:04:40,151 : INFO : EPOCH - 3 : training on 125206 raw words (38094 effective words) took 1.9s, 19862 effective words/s
# 2018-04-21 13:04:41,146 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-04-21 13:04:41,540 : INFO : EPOCH 4 - PROGRESS: at 60.37% examples, 16635 words/s, in_qsize 5, out_qsize 1
# 2018-04-21 13:04:41,541 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-04-21 13:04:41,800 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-04-21 13:04:41,804 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-04-21 13:04:41,813 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-21 13:04:41,818 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-21 13:04:41,819 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-21 13:04:41,820 : INFO : EPOCH - 4 : training on 125206 raw words (37972 effective words) took 1.7s, 22874 effective words/s
# 2018-04-21 13:04:42,663 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-04-21 13:04:43,058 : INFO : EPOCH 5 - PROGRESS: at 60.37% examples, 18698 words/s, in_qsize 5, out_qsize 1
# 2018-04-21 13:04:43,059 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-04-21 13:04:43,302 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-04-21 13:04:43,314 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-04-21 13:04:43,323 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-21 13:04:43,325 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-21 13:04:43,328 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-21 13:04:43,328 : INFO : EPOCH - 5 : training on 125206 raw words (38034 effective words) took 1.5s, 25350 effective words/s
# 2018-04-21 13:04:43,329 : INFO : training on a 626030 raw words (190070 effective words) took 8.7s, 21761 effective words/s
# 2018-04-21 13:04:43,330 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
# shows the similar articles to article with id = 100
print (d2v_model.docvecs.most_similar(100, topn = 10))
print(tokens[100])
# Out:
# [(13414, 0.7639433145523071), (3411, 0.7537654638290405), (10956, 0.7512814402580261), (13793, 0.7507666349411011), (11712, 0.748617947101593), (10428, 0.748516321182251), (17499, 0.7484363913536072), (1447, 0.7472888231277466), (3237, 0.7460149526596069), (11026, 0.7457857131958008)]
# ['geldpolitische', 'experiment', 'japan', 'europa', 'sorgen', 'wichtige', 'lehren', 'aufzeigen']

# %%
#cluster vectors into specific groups

NUM_CLUSTERS = 15

vectors = []

for token in tokens:
    vectors.append(d2v_model.infer_vector(token))
print("INFO: infer_vectors done.")

kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25, avoid_empty_clusters=True)

print("INFO: KMeansClusterer done.")
assigned_clusters = kclusterer.cluster(vectors, assign_clusters=True)
print("INFO: assign_clusters done.")

# %%
#Print the most frequent words in each clusters
from collections import Counter

clusters = assigned_clusters

for cluster_iter in list(set(clusters)):
    all_words = []
    for i in range(0,len(tokens)):
        sentence = tokens[i]
        cluster = clusters[i]
        if cluster == cluster_iter:
            all_words = all_words+sentence
    counts = Counter(all_words)
    print("Cluster: " + str(cluster_iter))
    print(counts.most_common(100))
    print("\n")
# Out:
# Cluster: 0
# [('krone', 4), ('politische', 4), ('neue', 4), ('serbien', 4), ('entwickelt', 3), ('kritisieren', 3), ('seien', 3), ('windows', 3), ('regisseur', 3), ('gestorben', 3), ('frankreichs', 2), ('sucht', 2), ('hoch', 2), ('situation', 2), ('fest', 2), ('verabschiedet', 2), ('krise', 2), ('zuvor', 2), ('android', 2), ('remis', 2), ('nutzungsrechte', 2), ('hollande', 2), ('aufs', 2), ('automatisch', 2), ('technik', 2), ('gleich', 2), ('erscheinen', 2), ('spielt', 2), ('kurz', 2), ('tiroler', 2), ('spur', 2), ('moore', 2), ('zeitung', 2), ('initiative', 2), ('erneut', 2), ('ermittlungen', 2), ('fokus', 2), ('mehrheit', 2), ('sollen', 2), ('kehrt', 2), ('besten', 2), ('drucker', 2), ('demonstration', 2), ('wochenende', 2), ('besser', 2), ('norden', 2), ('kritisierte', 2), ('angaben', 2), ('gewalt', 2), ('franziskus', 2), ('spitze', 2), ('kenia', 2), ('partner', 2), ('thriller', 2), ('kraft', 2), ('starken', 2), ('fallen', 2), ('entstehung', 2), ('finale', 2), ('klug', 2), ('kosovo', 2), ('konsumenten', 2), ('reagiert', 2), ('protestieren', 2), ('rahmen', 2), ('abseits', 2), ('voll', 2), ('fotos', 2), ('neos', 2), ('berliner', 2), ('mensch', 2), ('setzen', 2), ('folgt', 2), ('offenbar', 2), ('beketow', 1), ('besteht', 1), ('vki', 1), ('finanzierungsprobleme', 1), ('spanien', 1), ('anschlag', 1), ('modernisierung', 1), ('einflusses', 1), ('david', 1), ('oper', 1), ('papstes', 1), ('hotelgruppe', 1), ('lautet', 1), ('position', 1), ('katastrophenfonds', 1), ('minnesota', 1), ('beziehungsstreit', 1), ('quadratmeter', 1), ('generalleutnant', 1), ('weiss', 1), ('jennifer', 1), ('nennt', 1), ('misere', 1), ('schuldzuweisungen', 1), ('entwicklung', 1), ('reife', 1)]
#
#
# Cluster: 1
# [('sowie', 3), ('gefunden', 3), ('sollen', 3), ('neue', 3), ('wurde', 2), ('mehr', 2), ('angeboten', 2), ('prozent', 2), ('lau', 2), ('gesucht', 2), ('johannes', 2), ('beitrag', 2), ('dinge', 2), ('tisch', 2), ('anleihen', 2), ('fehlen', 2), ('ab', 2), ('wissenschafter', 2), ('wissen', 2), ('pestiziden', 1), ('videoaufnahmen', 1), ('cardiff', 1), ('fleischer', 1), ('bodenpersonals', 1), ('schwarzen', 1), ('reduziert', 1), ('demonstration', 1), ('pakistanische', 1), ('kritische', 1), ('voran', 1), ('leistungsgerechtes', 1), ('bienen', 1), ('gaben', 1), ('angedeutet', 1), ('arbeitsbedingungen', 1), ('viererkoalition', 1), ('ioma', 1), ('arabischen', 1), ('laufendes', 1), ('bier', 1), ('steuerung', 1), ('anfangs', 1), ('personalisierung', 1), ('beziehungen', 1), ('zweifel', 1), ('politiker', 1), ('gehandelt', 1), ('eignung', 1), ('vorberechneter', 1), ('kosmetik', 1), ('zusammenarbeit', 1), ('situation', 1), ('person', 1), ('medienarbeiter', 1), ('composite', 1), ('illegal', 1), ('adaptives', 1), ('jobbedingungen', 1), ('entwickelt', 1), ('mercedes', 1), ('freeman', 1), ('betrieb', 1), ('umbau', 1), ('rektorat', 1), ('konservative', 1), ('astronomische', 1), ('mohnanbau', 1), ('respekt', 1), ('motor', 1), ('grundlagenforscher', 1), ('offizierin', 1), ('geheimnisse', 1), ('vertraute', 1), ('englands', 1), ('setzten', 1), ('ergebnisse', 1), ('israelische', 1), ('masters', 1), ('marte', 1), ('wanderkapitalismus', 1), ('schafft', 1), ('landschaft', 1), ('schweiz', 1), ('feststellung', 1), ('krank', 1), ('erlitten', 1), ('seit', 1), ('firma', 1), ('zweite', 1), ('oberste', 1), ('bestimmt', 1), ('einigung', 1), ('jahresbeginn', 1), ('kommunikationsmitteln', 1), ('distrikt', 1), ('unfug', 1), ('balkanstaat', 1), ('ausarten', 1), ('fassbrause', 1), ('kinderliteratur', 1)]
#
#
# Cluster: 2
# [('mehr', 9), ('verfahren', 6), ('sorgt', 6), ('verletzte', 5), ('nutzen', 5), ('aufgenommen', 4), ('setzte', 4), ('geplante', 4), ('le', 4), ('gefordert', 4), ('verteidigungsminister', 4), ('wachsen', 4), ('gar', 4), ('justiz', 4), ('videos', 4), ('wissenschafter', 4), ('unterschriften', 4), ('unklar', 4), ('league', 4), ('proteste', 4), ('microsoft', 4), ('entwicklung', 4), ('geraten', 4), ('tritt', 4), ('neue', 4), ('beschluss', 4), ('windows', 4), ('sogar', 4), ('minister', 4), ('de', 4), ('hersteller', 4), ('fotos', 4), ('gebracht', 4), ('parteien', 4), ('handel', 4), ('sucht', 3), ('zeichnet', 3), ('positiv', 3), ('anlass', 3), ('ziehen', 3), ('wein', 3), ('prozent', 3), ('norbert', 3), ('erwarten', 3), ('ausstellung', 3), ('fokus', 3), ('zugang', 3), ('branche', 3), ('frankreich', 3), ('robert', 3), ('einstimmiger', 3), ('liefern', 3), ('belasten', 3), ('konzept', 3), ('abschied', 3), ('informationen', 3), ('themen', 3), ('schaden', 3), ('a', 3), ('aktuellen', 3), ('pen', 3), ('erlaubt', 3), ('andreas', 3), ('verliert', 3), ('neben', 3), ('politische', 3), ('daniel', 3), ('wolfgang', 3), ('version', 3), ('warnt', 3), ('festwochen', 3), ('demonstranten', 3), ('angeles', 3), ('champions', 3), ('zwei', 3), ('sammeln', 3), ('wandel', 3), ('start', 3), ('risiko', 3), ('kirche', 3), ('ortet', 3), ('rom', 3), ('politiker', 3), ('ursache', 3), ('marine', 3), ('krise', 3), ('prammer', 3), ('bericht', 3), ('islamisten', 3), ('brief', 3), ('eigene', 3), ('erstes', 3), ('kategorien', 3), ('unfall', 3), ('bezeichnet', 3), ('namen', 3), ('nehmen', 3), ('verzichtet', 3), ('familie', 3), ('warnung', 3)]
#
#
# Cluster: 3
# [('rabinowich', 7), ('julya', 7), ('goldpreis', 6), ('deutscher', 6), ('neue', 6), ('winter', 5), ('wiener', 5), ('untersucht', 5), ('verspricht', 5), ('bayern', 5), ('folgt', 5), ('hilfe', 4), ('australien', 4), ('fokus', 4), ('sorgt', 4), ('auto', 4), ('neben', 4), ('verbessern', 4), ('warnt', 4), ('ausgezeichnet', 4), ('droht', 4), ('umsetzung', 4), ('liste', 4), ('co', 4), ('iphone', 4), ('regeln', 4), ('gemacht', 4), ('sucht', 3), ('bord', 3), ('wohl', 3), ('rennen', 3), ('spieler', 3), ('forschung', 3), ('prozent', 3), ('sollten', 3), ('aktuelle', 3), ('ausstellung', 3), ('helfen', 3), ('meisten', 3), ('wien', 3), ('dortmund', 3), ('h', 3), ('schnell', 3), ('gerade', 3), ('betroffene', 3), ('m', 3), ('widmet', 3), ('a', 3), ('paris', 3), ('blick', 3), ('gar', 3), ('vielen', 3), ('erlitten', 3), ('schreiben', 3), ('echt', 3), ('kommenden', 3), ('gewann', 3), ('gewinnt', 3), ('patienten', 3), ('grenzen', 3), ('c', 3), ('heimische', 3), ('weist', 3), ('bessere', 3), ('autos', 3), ('besitzer', 3), ('erkenntnisse', 3), ('offen', 3), ('leicht', 3), ('gefordert', 3), ('haus', 3), ('roma', 3), ('beiden', 3), ('vorgeschlagen', 3), ('laufen', 3), ('erstes', 3), ('neun', 3), ('pianist', 3), ('frei', 3), ('erinnern', 3), ('saison', 3), ('erreichen', 3), ('wirken', 3), ('art', 3), ('wasser', 3), ('prozess', 3), ('autor', 3), ('eigentlich', 3), ('jedoch', 3), ('smartphone', 3), ('eigenes', 3), ('bekommt', 3), ('kriegsverbrechen', 3), ('entdeckt', 3), ('kehrt', 3), ('beste', 3), ('ergebnisse', 3), ('versuchen', 3), ('streit', 3), ('richtigen', 3)]
#
#
# Cluster: 4
# [('neue', 7), ('ab', 5), ('wurde', 4), ('beim', 4), ('mehr', 4), ('wien', 4), ('helfen', 3), ('wegen', 3), ('prozent', 3), ('menschen', 3), ('verzichten', 2), ('tablets', 2), ('christian', 2), ('anzeige', 2), ('zwei', 2), ('euro', 2), ('beginnt', 2), ('eis', 2), ('neuen', 2), ('de', 2), ('eigener', 2), ('umgewandelt', 1), ('luzia', 1), ('petri', 1), ('zahlreichen', 1), ('kauft', 1), ('restaurants', 1), ('reh', 1), ('instinktiv', 1), ('klage', 1), ('rechtliche', 1), ('aufsatz', 1), ('magnus', 1), ('petra', 1), ('chefdramaturgin', 1), ('minuten', 1), ('kurkuma', 1), ('professionelle', 1), ('stockt', 1), ('szenen', 1), ('gefunden', 1), ('tages', 1), ('transport', 1), ('dank', 1), ('steirer', 1), ('akzente', 1), ('frankreichs', 1), ('festival', 1), ('farben', 1), ('spielten', 1), ('damals', 1), ('gurgiser', 1), ('weibliche', 1), ('pilotfilm', 1), ('udine', 1), ('gucht', 1), ('insolventes', 1), ('knopf', 1), ('landeshauptmann', 1), ('monatsende', 1), ('nimmt', 1), ('dresden', 1), ('industrie', 1), ('seit', 1), ('eigentliche', 1), ('machte', 1), ('nutzerinnen', 1), ('parlament', 1), ('respekt', 1), ('sorgen', 1), ('internationaler', 1), ('stadtregierung', 1), ('beitritt', 1), ('saragossa', 1), ('zwiebel', 1), ('laufbahn', 1), ('stinklangweilige', 1), ('reinicke', 1), ('alexej', 1), ('version', 1), ('napolitano', 1), ('jahren', 1), ('kommen', 1), ('einfach', 1), ('fenerbahce', 1), ('hofer', 1), ('aktie', 1), ('kandidieren', 1), ('platzten', 1), ('physiker', 1), ('geisterspiele', 1), ('notbremse', 1), ('john', 1), ('hilfe', 1), ('schritte', 1), ('scheitern', 1), ('fremde', 1), ('pdf', 1), ('tier', 1), ('kirche', 1)]
#
#
# Cluster: 5
# [('mehr', 6), ('prozent', 3), ('gesellschaft', 3), ('debatte', 3), ('niederlage', 3), ('ursache', 2), ('london', 2), ('finanzministerin', 2), ('basis', 2), ('setzte', 2), ('erscheinen', 2), ('bayern', 2), ('fluss', 2), ('kindesalter', 2), ('heinz', 2), ('nutzerinnen', 2), ('madrid', 2), ('grad', 2), ('schwerer', 2), ('mobile', 2), ('zib', 2), ('frankreich', 2), ('november', 2), ('bedeutung', 2), ('julia', 2), ('hitzige', 2), ('sozialsystem', 2), ('planen', 2), ('ehemaliger', 2), ('verlassen', 2), ('informationen', 2), ('aufschrei', 2), ('protest', 2), ('risiko', 2), ('beschwerden', 2), ('ab', 2), ('sexismus', 2), ('cyanat', 1), ('virusinfektionen', 1), ('verordnung', 1), ('reduziert', 1), ('plan', 1), ('verzichten', 1), ('weiters', 1), ('corp', 1), ('restauratorengruppe', 1), ('vierten', 1), ('plus', 1), ('verletzten', 1), ('spannendes', 1), ('anfangs', 1), ('pazifik', 1), ('dreifachsieg', 1), ('kunststoffmaterial', 1), ('digitalfunk', 1), ('illner', 1), ('genfer', 1), ('ruft', 1), ('schutz', 1), ('vermurungen', 1), ('positiv', 1), ('dank', 1), ('magazin', 1), ('entwickelt', 1), ('kontraproduktiv', 1), ('flut', 1), ('widerstands', 1), ('skandinavische', 1), ('tatverdachts', 1), ('beleben', 1), ('positionspapier', 1), ('recyceltem', 1), ('quartetts', 1), ('hotel', 1), ('fayyads', 1), ('deck', 1), ('trend', 1), ('aufstiegsrennen', 1), ('erdgas', 1), ('schwellung', 1), ('konzentrierte', 1), ('unterzeichneten', 1), ('pescatore', 1), ('heftige', 1), ('red', 1), ('chinesen', 1), ('geschrieben', 1), ('putzer', 1), ('risikobereite', 1), ('kapitals', 1), ('oppositionsvorschlag', 1), ('gegenwehr', 1), ('freilassung', 1), ('internationaler', 1), ('abgeschlossen', 1), ('wohl', 1), ('insolvente', 1), ('kurs', 1), ('harads', 1), ('saragossa', 1)]
#
#
# Cluster: 6
# [('mehr', 13), ('prozent', 8), ('neue', 8), ('wurde', 7), ('erneut', 7), ('warnt', 6), ('konzern', 6), ('film', 6), ('berichtet', 6), ('zeitung', 5), ('droht', 5), ('karriere', 5), ('koalition', 5), ('weltweit', 5), ('zahlreiche', 5), ('offenbar', 5), ('geplante', 4), ('schwer', 4), ('hofft', 4), ('drei', 4), ('ausstellung', 4), ('sprechen', 4), ('besser', 4), ('red', 4), ('bischof', 4), ('gelegt', 4), ('gar', 4), ('fest', 4), ('hohe', 4), ('tiroler', 4), ('neben', 4), ('dennoch', 4), ('form', 4), ('umgang', 4), ('union', 4), ('protest', 4), ('weit', 4), ('bekannt', 4), ('demokratie', 4), ('ehemalige', 4), ('microsoft', 4), ('band', 4), ('helfen', 4), ('bericht', 4), ('gegeben', 4), ('parlament', 4), ('deutscher', 4), ('paszek', 4), ('trainer', 4), ('san', 4), ('bull', 4), ('samsung', 4), ('gemeinsam', 4), ('soldaten', 4), ('klinik', 4), ('tv', 4), ('hersteller', 4), ('martin', 4), ('gemacht', 4), ('paris', 4), ('microsofts', 4), ('debatte', 4), ('berlin', 4), ('pc', 3), ('richtung', 3), ('institutionen', 3), ('nordkorea', 3), ('wirbt', 3), ('steuern', 3), ('plattform', 3), ('fokus', 3), ('branche', 3), ('premier', 3), ('langfristig', 3), ('streit', 3), ('treffen', 3), ('verletzte', 3), ('informiert', 3), ('vergewaltigungen', 3), ('vorerst', 3), ('angeblich', 3), ('stimme', 3), ('projekt', 3), ('allein', 3), ('produkte', 3), ('abschied', 3), ('wartet', 3), ('spanischen', 3), ('fernsehen', 3), ('partie', 3), ('nutzer', 3), ('apple', 3), ('aktuellen', 3), ('konnten', 3), ('einfluss', 3), ('kostenlose', 3), ('hoch', 3), ('regionale', 3), ('verbesserung', 3), ('sicherheit', 3)]
#
#
# Cluster: 7
# [('wurde', 3), ('prozent', 3), ('weigerung', 2), ('beim', 2), ('einreise', 2), ('verweigert', 2), ('mehr', 2), ('drei', 2), ('laut', 2), ('fixiert', 2), ('landen', 2), ('schaffen', 2), ('suche', 2), ('linie', 2), ('angriffe', 2), ('touristen', 2), ('sah', 2), ('neue', 2), ('ab', 2), ('de', 2), ('antrag', 1), ('gastiert', 1), ('voran', 1), ('restaurants', 1), ('hoch', 1), ('arbeitsweise', 1), ('p', 1), ('australierin', 1), ('russische', 1), ('atomwaffen', 1), ('weinzinger', 1), ('bernadette', 1), ('handel', 1), ('verlassen', 1), ('abgang', 1), ('investorentermine', 1), ('karenz', 1), ('radiostation', 1), ('kreatives', 1), ('karte', 1), ('festlegen', 1), ('budget', 1), ('erteilt', 1), ('problem', 1), ('bildern', 1), ('rettungsschirm', 1), ('van', 1), ('heimste', 1), ('teilweise', 1), ('neuem', 1), ('ziel', 1), ('bundesministers', 1), ('philosophen', 1), ('eingebrochen', 1), ('kapitaleinsatzes', 1), ('bord', 1), ('ungarische', 1), ('stammen', 1), ('schwerpunkt', 1), ('leibovitz', 1), ('aufgelassenen', 1), ('reisenden', 1), ('niveau', 1), ('wichtigsten', 1), ('ganay', 1), ('pariser', 1), ('chinesen', 1), ('technologie', 1), ('inszenierung', 1), ('inkubator', 1), ('shortland', 1), ('natalia', 1), ('etwaige', 1), ('flaschen', 1), ('meistern', 1), ('gift', 1), ('wicker', 1), ('preisverleihung', 1), ('beantragt', 1), ('konzert', 1), ('figurinen', 1), ('heranwachsenden', 1), ('formalen', 1), ('facebook', 1), ('euro', 1), ('schritt', 1), ('mobilen', 1), ('spiegel', 1), ('norden', 1), ('jahren', 1), ('entspannt', 1), ('leitete', 1), ('verstandene', 1), ('wichtige', 1), ('bryans', 1), ('entdeckt', 1), ('rubins', 1), ('verschwundenen', 1), ('kaufen', 1), ('zweifelsfall', 1)]
#
#
# Cluster: 8
# [('neue', 5), ('update', 5), ('prozent', 4), ('mehr', 4), ('beteiligt', 4), ('internationale', 4), ('weist', 4), ('syrische', 3), ('per', 3), ('bester', 3), ('app', 3), ('werte', 3), ('mord', 3), ('parlament', 3), ('sorgen', 3), ('konsole', 3), ('preis', 3), ('ausgezeichnet', 3), ('israels', 3), ('folgt', 3), ('sommer', 3), ('italien', 3), ('erneut', 3), ('moment', 2), ('red', 2), ('klagenfurt', 2), ('mursi', 2), ('setzte', 2), ('experte', 2), ('bildung', 2), ('stark', 2), ('geehrt', 2), ('fertig', 2), ('bundesstaat', 2), ('schwer', 2), ('erscheinen', 2), ('bein', 2), ('ausstellung', 2), ('krankheit', 2), ('zeitung', 2), ('sprechen', 2), ('kleine', 2), ('venedig', 2), ('fokus', 2), ('staatschef', 2), ('gesetz', 2), ('cup', 2), ('unfall', 2), ('chavez', 2), ('wien', 2), ('robert', 2), ('streit', 2), ('hochschulen', 2), ('rapper', 2), ('fortsetzen', 2), ('barcelona', 2), ('zusammenarbeit', 2), ('van', 2), ('verletzte', 2), ('israel', 2), ('einigung', 2), ('gefordert', 2), ('kanzler', 2), ('finanzen', 2), ('allein', 2), ('sorgt', 2), ('roman', 2), ('premier', 2), ('fester', 2), ('blieb', 2), ('begriff', 2), ('vertreter', 2), ('queen', 2), ('verantwortung', 2), ('nutzer', 2), ('beraten', 2), ('wirklich', 2), ('klein', 2), ('konkurrenz', 2), ('chance', 2), ('gegnerinnen', 2), ('armen', 2), ('vielen', 2), ('konnten', 2), ('ausschreitungen', 2), ('levante', 2), ('g', 2), ('hohe', 2), ('cengiz', 2), ('aussagen', 2), ('insbesondere', 2), ('getroffen', 2), ('sturm', 2), ('fed', 2), ('autor', 2), ('irak', 2), ('absolut', 2), ('verbessert', 2), ('os', 2), ('zypern', 2)]
#
#
# Cluster: 9
# [('fokus', 4), ('tagen', 4), ('kritisieren', 3), ('arbeitswelt', 3), ('meter', 3), ('nennt', 3), ('meisten', 3), ('st', 3), ('neue', 3), ('jahren', 3), ('wahrscheinlich', 3), ('konkurrenz', 3), ('wurde', 3), ('angreifer', 3), ('mehr', 3), ('versucht', 3), ('washington', 3), ('vergleich', 3), ('brigitte', 3), ('strache', 3), ('ehemalige', 3), ('ab', 3), ('sucht', 2), ('zeichnet', 2), ('beinahe', 2), ('geworden', 2), ('verwendet', 2), ('bewusstsein', 2), ('starb', 2), ('bruji', 2), ('vertragsbedingungen', 2), ('denen', 2), ('ziel', 2), ('passagieren', 2), ('deutsch', 2), ('grab', 2), ('lebt', 2), ('teamchef', 2), ('entsteht', 2), ('staat', 2), ('leisten', 2), ('drei', 2), ('gefahren', 2), ('konzern', 2), ('mehrheit', 2), ('virtuellen', 2), ('ivan', 2), ('bezahlen', 2), ('ausreichend', 2), ('a', 2), ('kleine', 2), ('kelly', 2), ('liste', 2), ('premier', 2), ('film', 2), ('baldige', 2), ('sozialdemokraten', 2), ('verantwortlich', 2), ('pianist', 2), ('teurer', 2), ('burgenlandroma', 2), ('innsbruck', 2), ('umstrittene', 2), ('schwerpunkt', 2), ('verletzte', 2), ('schweiz', 2), ('musikverein', 2), ('einst', 2), ('einigung', 2), ('vernichteten', 2), ('attacke', 2), ('burgenlandkroatischen', 2), ('fortsetzung', 2), ('physik', 2), ('miteinander', 2), ('colorado', 2), ('belasten', 2), ('finanziellen', 2), ('aufgrund', 2), ('schaden', 2), ('tirol', 2), ('kammerton', 2), ('nordkosovo', 2), ('hagel', 2), ('reagiert', 2), ('spital', 2), ('aufbauarbeit', 2), ('widerstand', 2), ('galerie', 2), ('innerhalb', 2), ('islanders', 2), ('volksgruppe', 2), ('forderungen', 2), ('donauinsel', 2), ('schwer', 2), ('kepler', 2), ('anmerkungen', 2), ('zypern', 2), ('sprecherin', 2), ('rebellen', 2)]
# Cluster: 10
# [('mehr', 9), ('legt', 6), ('belasten', 5), ('schwache', 5), ('ehemaligen', 5), ('tat', 5), ('spezial', 5), ('nimmt', 5), ('schauspieler', 5), ('untersucht', 5), ('stelle', 5), ('erhielt', 5), ('zweifel', 4), ('hilfe', 4), ('erfolgreich', 4), ('gefordert', 4), ('schweden', 4), ('vorgestellt', 4), ('gewinnt', 4), ('ab', 4), ('konnte', 4), ('zwei', 4), ('tablets', 4), ('angebot', 4), ('zuvor', 4), ('barbara', 4), ('missbrauch', 4), ('tod', 4), ('feiern', 4), ('zahlreiche', 4), ('berichtet', 4), ('folgt', 4), ('neuem', 4), ('protest', 4), ('finanzielle', 3), ('red', 3), ('connected', 3), ('doppelzimmer', 3), ('weiterer', 3), ('android', 3), ('geehrt', 3), ('region', 3), ('ziehen', 3), ('lebt', 3), ('chef', 3), ('wirkung', 3), ('vergeben', 3), ('sprechen', 3), ('fokus', 3), ('st', 3), ('abgesagt', 3), ('treffen', 3), ('freiheit', 3), ('breite', 3), ('verletzte', 3), ('sorgen', 3), ('kanzler', 3), ('vorerst', 3), ('angeblich', 3), ('elf', 3), ('sorgt', 3), ('premier', 3), ('sprach', 3), ('theater', 3), ('a', 3), ('wahlkampf', 3), ('meint', 3), ('grenze', 3), ('warnen', 3), ('wurde', 3), ('beim', 3), ('entwickler', 3), ('christian', 3), ('gefunden', 3), ('reaktion', 3), ('kaufpreis', 3), ('museum', 3), ('gewann', 3), ('syrien', 3), ('grenzen', 3), ('update', 3), ('ausgezeichnet', 3), ('seien', 3), ('gegeben', 3), ('gestorben', 3), ('freiheitlichen', 3), ('verdacht', 3), ('leitung', 3), ('j', 3), ('interesse', 3), ('user', 3), ('ebenfalls', 3), ('beiden', 3), ('wetter', 3), ('erstes', 3), ('kleine', 3), ('liste', 3), ('entscheidenden', 3), ('werbung', 3), ('september', 3)]
#
#
# Cluster: 11
# [('prozent', 4), ('gewerkschaft', 3), ('wurde', 2), ('kritisch', 2), ('anklagen', 2), ('seidl', 2), ('regisseur', 2), ('tribute', 2), ('wirft', 2), ('tablet', 2), ('sowie', 2), ('seite', 2), ('belasten', 2), ('neue', 2), ('linzer', 2), ('ulrich', 2), ('fisch', 2), ('premier', 2), ('tausende', 2), ('entscheidet', 2), ('komponist', 2), ('strache', 2), ('finale', 2), ('neuem', 2), ('staatlichen', 2), ('grenzen', 2), ('ali', 2), ('wien', 2), ('politischen', 2), ('klagenfurter', 2), ('wojcieszek', 2), ('ausgezeichnet', 2), ('besteht', 1), ('luxe', 1), ('dagegen', 1), ('pc', 1), ('parsons', 1), ('spanien', 1), ('suite', 1), ('tiger', 1), ('sucht', 1), ('verband', 1), ('klinke', 1), ('amelie', 1), ('unmoralische', 1), ('gaben', 1), ('mordes', 1), ('arbeitsbedingungen', 1), ('geworden', 1), ('silber', 1), ('wikinger', 1), ('einmaleffekte', 1), ('arabischen', 1), ('hand', 1), ('arbeitskampf', 1), ('plenum', 1), ('modekette', 1), ('aufnahmen', 1), ('projekt', 1), ('fallah', 1), ('seele', 1), ('zweifel', 1), ('freskomalereien', 1), ('global', 1), ('produziert', 1), ('kriterien', 1), ('przemyslaw', 1), ('dank', 1), ('teilweise', 1), ('schmeckende', 1), ('richtung', 1), ('anlagezertifikate', 1), ('tempo', 1), ('drehbuchautorin', 1), ('vorzuweisen', 1), ('jugendliche', 1), ('gastspiels', 1), ('besser', 1), ('vorjahr', 1), ('einziger', 1), ('neukunden', 1), ('unverletzt', 1), ('augustin', 1), ('satlizenz', 1), ('spannendsten', 1), ('walter', 1), ('autorin', 1), ('rekonstruiert', 1), ('verliebt', 1), ('wintersechseck', 1), ('umstritten', 1), ('buddhistische', 1), ('renovierung', 1), ('illusionen', 1), ('aufzeigen', 1), ('bua', 1), ('abstiegskandidaten', 1), ('schauspielkunst', 1), ('angesichts', 1), ('vermarktungsproblem', 1)]
#
#
# Cluster: 12
# [('visier', 7), ('wurde', 7), ('prozent', 6), ('informationen', 6), ('streit', 5), ('premier', 5), ('anschlag', 5), ('gefunden', 5), ('protest', 5), ('microsoft', 5), ('haus', 5), ('verhindern', 5), ('gemeinsame', 5), ('sommer', 5), ('schriftsteller', 5), ('gamestandard', 4), ('internationalen', 4), ('finale', 4), ('exklusive', 4), ('stunde', 4), ('verlost', 4), ('richter', 4), ('droht', 4), ('markt', 4), ('tritt', 4), ('wohnen', 4), ('neue', 4), ('vorwurf', 4), ('warnung', 4), ('angebot', 4), ('schnell', 4), ('forderungen', 4), ('co', 4), ('ehemalige', 4), ('vorgeworfen', 4), ('kontrolle', 4), ('grenzen', 4), ('schauspieler', 4), ('setzen', 4), ('bord', 3), ('weiterer', 3), ('android', 3), ('geehrt', 3), ('erfolgreich', 3), ('aktion', 3), ('app', 3), ('familie', 3), ('reihe', 3), ('aufgenommen', 3), ('empfiehlt', 3), ('alternative', 3), ('erhalten', 3), ('eigener', 3), ('sorgen', 3), ('feuer', 3), ('angeblich', 3), ('budapest', 3), ('alpe', 3), ('adria', 3), ('schweden', 3), ('g', 3), ('a', 3), ('deutscher', 3), ('reise', 3), ('ab', 3), ('josef', 3), ('tv', 3), ('christian', 3), ('verhandlungen', 3), ('erlaubt', 3), ('hypo', 3), ('staatsanwaltschaft', 3), ('verbessern', 3), ('besuch', 3), ('favoriten', 3), ('beute', 3), ('ausgezeichnet', 3), ('tiere', 3), ('vergangenheit', 3), ('seien', 3), ('wert', 3), ('wissen', 3), ('unverletzt', 3), ('norden', 3), ('zwei', 3), ('gold', 3), ('mitte', 3), ('unklar', 3), ('reform', 3), ('euro', 3), ('kino', 3), ('bekannt', 3), ('galt', 3), ('entschieden', 3), ('proteste', 3), ('kleinen', 3), ('karriere', 3), ('interesse', 3), ('ermittlungen', 3), ('obama', 3)]
#
#
# Cluster: 13
# [('neue', 26), ('wurde', 22), ('mehr', 20), ('wiener', 19), ('prozent', 18), ('sollen', 18), ('ab', 15), ('laut', 13), ('wien', 12), ('zwei', 12), ('beim', 11), ('wegen', 11), ('dass', 11), ('euro', 10), ('jahren', 10), ('jahr', 8), ('menschen', 7), ('seit', 7), ('gibt', 7), ('bereits', 6), ('fordert', 6), ('regierung', 6), ('drei', 5), ('jahre', 5), ('neuen', 5), ('frauen', 5), ('wurden', 4), ('sieg', 4), ('schwer', 3), ('immer', 3), ('gruppe', 3), ('forscher', 3), ('lesben', 3), ('geht', 3), ('haft', 3), ('auszeichnung', 3), ('group', 3), ('sachen', 3), ('vorgeworfen', 3), ('dotiert', 3), ('vier', 3), ('suche', 3), ('april', 3), ('ungarn', 3), ('millionen', 3), ('schon', 3), ('berlin', 3), ('preise', 3), ('steigen', 3), ('gleiche', 2), ('verzichtete', 2), ('executive', 2), ('variante', 2), ('rund', 2), ('siege', 2), ('auflagen', 2), ('eins', 2), ('massenproduktion', 2), ('aufgenommen', 2), ('name', 2), ('gegner', 2), ('vorbei', 2), ('haus', 2), ('starten', 2), ('iran', 2), ('entwicklung', 2), ('investoren', 2), ('evaluierung', 2), ('franzosen', 2), ('freude', 2), ('sechs', 2), ('vorschlag', 2), ('lena', 2), ('beschlagnahmt', 2), ('helfen', 2), ('stuttgart', 2), ('finanzierung', 2), ('zuwachs', 2), ('abgesagt', 2), ('treffen', 2), ('homo', 2), ('luft', 2), ('verboten', 2), ('einst', 2), ('feuer', 2), ('macht', 2), ('regisseur', 2), ('vienna', 2), ('leben', 2), ('vertrag', 2), ('verfahren', 2), ('weitere', 2), ('unternehmens', 2), ('kostet', 2), ('holt', 2), ('ersten', 2), ('streit', 2), ('hardware', 2), ('prototyp', 2), ('zweite', 2)]
#
#
# Cluster: 14
# [('mehr', 554), ('euro', 455), ('prozent', 423), ('neue', 386), ('millionen', 353), ('ab', 350), ('zwei', 338), ('wurde', 336), ('wiener', 330), ('wien', 320), ('dass', 298), ('jahren', 281), ('sollen', 271), ('drei', 264), ('beim', 261), ('laut', 255), ('seit', 251), ('wegen', 250), ('gibt', 229), ('menschen', 210), ('neuen', 206), ('immer', 203), ('jahre', 191), ('wurden', 188), ('bereits', 186), ('vier', 183), ('geht', 181), ('rund', 177), ('frauen', 171), ('ersten', 168), ('jahr', 167), ('regierung', 167), ('viele', 166), ('sieg', 163), ('zeigt', 163), ('mai', 162), ('forscher', 156), ('ende', 153), ('schon', 153), ('sieht', 148), ('neues', 146), ('usa', 144), ('welt', 144), ('leben', 144), ('erste', 142), ('macht', 142), ('neuer', 140), ('april', 138), ('kommt', 137), ('weitere', 133), ('steht', 133), ('bleibt', 132), ('unternehmen', 128), ('zehn', 128), ('warum', 127), ('weniger', 126), ('fordert', 123), ('deutsche', 122), ('zeit', 120), ('heute', 118), ('platz', 117), ('kritik', 116), ('kinder', 115), ('polizei', 115), ('sei', 115), ('sagt', 114), ('bisher', 114), ('gut', 113), ('erstmals', 113), ('deutschland', 112), ('the', 111), ('juni', 109), ('wer', 109), ('gehen', 109), ('geld', 109), ('sehen', 108), ('kommen', 107), ('woche', 107), ('milliarden', 106), ('fast', 105), ('trotz', 104), ('europa', 103), ('land', 103), ('sechs', 102), ('erwartet', 101), ('worden', 100), ('salzburg', 100), ('new', 97), ('dabei', 97), ('lassen', 95), ('statt', 94), ('thema', 94), ('deutschen', 94), ('geben', 94), ('tag', 93), ('studie', 92), ('stadt', 91), ('setzt', 91), ('dollar', 91), ('orf', 91)]
